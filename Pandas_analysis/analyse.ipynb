# %%
import pandas as pd

# %%
df = pd.read_csv('veg_plant_height.csv')

df
# Out:
#             plant_name UOM  Low_End_of_Range  High_End_of_Range
# 0            Artichoke   F                 4                  5
# 1              Arugula   I                 8                 10
# 2            Asparagus   F                 4                  6
# 3          Beans, bush   I                24                 30
# 4   Beans, lima (bush)   I                24                 36
# 5          Beans, pole   F                 8                 12
# 6                Beets   I                 4                 12
# 7             Broccoli   I                18                 24
# 8      Brussel sprouts   I                24                 36
# 9              Cabbage   I                12                 18
# 10             Carrots   I                 6                 15
# 11         Cauliflower   I                12                 30
# 12              Celery   I                18                 24
# 13               Chard   I                12                 30
# ...

# %% [markdown]
# # Filtering and Ordering

# %%
df[df["Low_End_of_Range"] < 10]
# Out:
#      plant_name UOM  Low_End_of_Range  High_End_of_Range
# 0     Artichoke   F                 4                  5
# 1       Arugula   I                 8                 10
# 2     Asparagus   F                 4                  6
# 5   Beans, pole   F                 8                 12
# 6         Beets   I                 4                 12
# 10      Carrots   I                 6                 15
# 14      Edamame   F                 1                  3
# 15         Corn   F                 4                  8
# 16     Cucumber   F                 1                  5
# 17     Eggplant   F                 1                  3
# 18       Endive   I                 6                  9
# 21     Kohlrabi   I                 9                 12
# 23      Lettuce   I                 6                 12
# 24         Okra   F                 2                  8
# 25       Onions   I                 8                 24
# ...

# %%
specific_veg = ["Spinach", "Onions"]

df[df["plant_name"].isin(specific_veg)]
# Out:
#    plant_name UOM  Low_End_of_Range  High_End_of_Range
# 25     Onions   I                 8                 24
# 33    Spinach   I                 6                 15

# %%
df[df["plant_name"].str.contains("Squash")]
# Out:
#         plant_name UOM  Low_End_of_Range  High_End_of_Range
# 35  Squash, summer   I                12                 24
# 36  Squash, winter   I                12                 24

# %%
df2 = df.set_index('plant_name')
df2
# Out:
#                    UOM  Low_End_of_Range  High_End_of_Range
# plant_name
# Artichoke            F                 4                  5
# Arugula              I                 8                 10
# Asparagus            F                 4                  6
# Beans, bush          I                24                 30
# Beans, lima (bush)   I                24                 36
# Beans, pole          F                 8                 12
# Beets                I                 4                 12
# Broccoli             I                18                 24
# Brussel sprouts      I                24                 36
# Cabbage              I                12                 18
# Carrots              I                 6                 15
# Cauliflower          I                12                 30
# Celery               I                18                 24
# Chard                I                12                 30
# ...

# %%
df2.filter(items=["Low_End_of_Range", "High_End_of_Range"])
# Out:
#                     Low_End_of_Range  High_End_of_Range
# plant_name
# Artichoke                          4                  5
# Arugula                            8                 10
# Asparagus                          4                  6
# Beans, bush                       24                 30
# Beans, lima (bush)                24                 36
# Beans, pole                        8                 12
# Beets                              4                 12
# Broccoli                          18                 24
# Brussel sprouts                   24                 36
# Cabbage                           12                 18
# Carrots                            6                 15
# Cauliflower                       12                 30
# Celery                            18                 24
# Chard                             12                 30
# Edamame                            1                  3
# Corn                               4                  8
# ...

# %%
df2.filter(items=["Spinach"], axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [Artichoke, Arugula, Asparagus, Beans, bush, Beans, lima (bush), Beans, pole, Beets, Broccoli, Brussel sprouts, Cabbage, Carrots, Cauliflower, Celery, Chard, Edamame, Corn, Cucumber, Eggplant, Endive, Garlic, Kale, Kohlrabi, Leeks, Lettuce, Okra, Onions, Parsnips, Peas, Peppers, hot, Peppers, bell, Potatoes, Pumpkin, Radishes, Spinach, Rutabaga, Squash, summer, Squash, winter, Sweet potato, Tomatoes, Turnips, Zucchini]

# %%
df2.filter(items=["Spinach"], axis=0)
# Out:
#         UOM  Low_End_of_Range  High_End_of_Range
# Spinach   I                 6                 15
